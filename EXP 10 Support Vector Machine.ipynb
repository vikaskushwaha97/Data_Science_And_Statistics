# %%
#EXP NO: 10

# %%
#Aim: To create a Support Vector Machine model that separates classes by finding the best decision boundary.

# %%
#Name:Srushti Tade
#Roll no: 62
#sec: B
#subject: EMERGING TECH. LAB - I
#Data:

# %%
import pandas as pd 
import numpy as np
import os

# %%
os.chdir("C:\\Users\\ASUS\\Downloads")

# %%
data=pd.read_csv("heart.csv")

# %%
x=data.drop("target", axis=1)
y=data["target"]

# %%
#splitting the data into training and testing data sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn import svm
from sklearn.metrics import accuracy_score

# %%
svm=svm.SVC()
svm.fit(x_train, y_train)
# Out:
# SVC()

# %%
y_pred=svm.predict(x_test)

# %%
accuracy_score (y_test,y_pred)
# Out:
# 0.7049180327868853

# %%
from sklearn import svm
import numpy as np
import matplotlib.pyplot as plt

# Select features and target
X_vis = x_train[['age', 'chol']]
y_vis = y_train

# Train SVM
model = svm.SVC(kernel='linear')
model.fit(X_vis, y_vis)

# Plot points
plt.scatter(X_vis['age'], X_vis['chol'], c=y_vis, cmap='coolwarm', edgecolors='k')

# Create grid for decision boundary
xx, yy = np.meshgrid(np.linspace(X_vis['age'].min()-1, X_vis['age'].max()+1, 500),
                     np.linspace(X_vis['chol'].min()-1, X_vis['chol'].max()+1, 500))

Z = model.decision_function(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)

# Plot decision boundary and margins
plt.contour(xx, yy, Z, levels=[0], colors='k', linewidths=2)
plt.contour(xx, yy, Z, levels=[-1, 1], colors='k', linestyles='dashed')

plt.title("SVM Decision Boundary: Age vs Cholesterol")
plt.xlabel('Age')
plt.ylabel('Cholesterol')
plt.show()
# Out:
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
#Conclusion

# %%
#The SVM model successfully classified the data by finding the optimal decision boundary that separates different classes.
#It proved effective in achieving accurate and robust classification results.
