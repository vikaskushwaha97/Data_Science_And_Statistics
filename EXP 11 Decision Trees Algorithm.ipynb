# %%
#EXP NO: 11

# %%
#AIM: To build a predictive model using the Decision Tree algorithm for making data-driven decisions.

# %%
#Name:Srushti Tade
#Roll no: 62
#sec: B
#subject: EMERGING TECH. LAB - I
#Data:

# %%
import pandas as pd 
import numpy as np
import os

# %%
os.chdir("C:\\Users\\ASUS\\Downloads")

# %%
data=pd.read_csv("heart.csv")

# %%
x=data.drop("target", axis=1)
y=data["target"]

# %%
#splitting the data into training and testing data sets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred4=dt.predict(x_test)

# %%
accuracy_score (y_test,y_pred4)
# Out:
# 0.8360655737704918

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

model = DecisionTreeClassifier(max_depth=3)  # limit depth
model.fit(x, y)

plt.figure(figsize=(12, 8))
plot_tree(model, filled=True, feature_names=x.columns, class_names=['No', 'Yes'])
plt.title("Simplified Decision Tree (max_depth=3)")
plt.show()

# %%
#Conclusion

# %%
#The Decision Tree model was successfully built to make data-driven predictions by learning patterns from the dataset.
#It provided clear and interpretable decision rules, enabling effective and accurate decision-making.
